# %% [markdown]
# # Multiple witness alignment with skipgrams, pandas version

# %%
# %%html
# <!-- tables should be left-aligned-->
# <style>
# table {margin-left:0 !important}
# </style>
# Out:
# <!-- tables should be left-aligned-->
# <style>
# table {margin-left:0 !important}
# </style>

# %% [markdown]
# ## Problem description
#
# ### Input
#
# ```json
# {'wit1': ['a', 'b', 'c', 'a', 'd', 'e'],
#  'wit2': ['a', 'e', 'c', 'd'],
#  'wit3': ['a', 'd', 'b']
# }
# ```
#
# ### Expected output
#
# siglum | token | token | token | token | token | token | token | token
# ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ----
# wit1  | #start | a | b | c | a | d | e | #end
# wit2  | #start | a | e | c | - | d | - | #end
# wit3  | #start | a | - | - | - | d | b | #end
#
# ### Topological sort
#
# (Partly ordered)
#
# `a (b e) c a d (e b)`

# %% [markdown]
# ## Load libraries and configure noteook display parameters

# %%
import pandas as pd
import collections # for defaultdict
from bitarray import bitarray
import pprint as pp
from prettytable import PrettyTable # not part of anaconda distribution; install with pip
import pandas_profiling # https://towardsdatascience.com/10-simple-hacks-to-speed-up-your-data-analysis-in-python-ec18c6396e6b
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# ## Sample data and housekeeping

# %%
# sample data with a bit of repetition
witnessData = {'wit1': ['a', 'b', 'c', 'a', 'd', 'e'],
               'wit2': ['a', 'e', 'c', 'd'],
               'wit3': ['a', 'd', 'b']}

# fake stoplist, to ensure that we can identify stopwords and process them last
stoplist = {'a', 'c'} # set

# bitArrays is used to keep track of which witness tokens have already been processed
bitArrays = {k: bitarray(len(witnessData[k])) for k in witnessData}  # create a bitarray the length of each witness
for ba in bitArrays.values():  # initialize bitarrays to all 0 values
    ba.setall(0)

# %% [markdown]
# ## Create _common sequence table_ (`csTable`)
#
# Record location of all skipgrams in all witnesses.

# %%
# csTable: dictionary, in which
#   key: two-item tuple representing skipgram normalized token values (token[0], token[1])
#   value: list of three-item tuples records all locations where the key occurs: (siglum, offset[0], offset[1])
#     In Real Life:
#       values will include the t values corresponding to the normalized token values
#       use a named tuple or dataclass (https://realpython.com/python-data-classes/)
# In this test sample, we find all skip bigrams; in Real Life we would specify parameters for:
#   size of skipgram (bi, tri-, etc.; here bi-)
#   size of window (maximum distance between first and last members of skipgram; here the full witness length)
#   maximum size of skip between members of skipgram (here constrained only by size of window)
csTable = collections.defaultdict(list)
for key, value in witnessData.items(): # key is siglum, value is list of normalized token readings
    # in Real Life the value would also include a non-normalized t property
    for first in range(len(value)): # all first items in bigram
        for second in range(first + 1, len(value)): # pair with all following items
            csTable[(value[first], value[second])].append((key, first, second))
csTable
# Out:
# defaultdict(list,
#             {('a', 'b'): [('wit1', 0, 1), ('wit3', 0, 2)],
#              ('a', 'c'): [('wit1', 0, 2), ('wit2', 0, 2)],
#              ('a', 'a'): [('wit1', 0, 3)],
#              ('a', 'd'): [('wit1', 0, 4),
#               ('wit1', 3, 4),
#               ('wit2', 0, 3),
#               ('wit3', 0, 1)],
#              ('a', 'e'): [('wit1', 0, 5), ('wit1', 3, 5), ('wit2', 0, 1)],
#              ('b', 'c'): [('wit1', 1, 2)],
#              ('b', 'a'): [('wit1', 1, 3)],
#              ('b', 'd'): [('wit1', 1, 4)],
#              ('b', 'e'): [('wit1', 1, 5)],
#              ('c', 'a'): [('wit1', 2, 3)],
#              ('c', 'd'): [('wit1', 2, 4), ('wit2', 2, 3)],
#              ('c', 'e'): [('wit1', 2, 5)],
#              ('d', 'e'): [('wit1', 4, 5)],
#              ('e', 'c'): [('wit2', 1, 2)],
#              ('e', 'd'): [('wit2', 1, 3)],
#              ('d', 'b'): [('wit3', 1, 2)]})

# %% [markdown]
# ## Construct df and add information needed for ordered traversal

# %%
# convert to series before df since list lengths vary
csSeries = pd.Series(csTable)
csSeries # creates a NultiIndex, which we will want to flatten
# Out:
# a  b                                [(wit1, 0, 1), (wit3, 0, 2)]
#    c                                [(wit1, 0, 2), (wit2, 0, 2)]
#    a                                              [(wit1, 0, 3)]
#    d    [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
#    e                  [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# b  c                                              [(wit1, 1, 2)]
#    a                                              [(wit1, 1, 3)]
#    d                                              [(wit1, 1, 4)]
#    e                                              [(wit1, 1, 5)]
# c  a                                              [(wit1, 2, 3)]
#    d                                [(wit1, 2, 4), (wit2, 2, 3)]
#    e                                              [(wit1, 2, 5)]
# d  e                                              [(wit1, 4, 5)]
# e  c                                              [(wit2, 1, 2)]
#    d                                              [(wit2, 1, 3)]
# d  b                                              [(wit3, 1, 2)]
# dtype: object

# %%
# convert series to dataframe, flatten MultiIndex, label columns
csDf = pd.DataFrame(csSeries).reset_index()
csDf.columns = ["first", "second", "locations"]
csDf
# Out:
#    first second                                                 locations
# 0      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 1      a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 2      a      a                                            [(wit1, 0, 3)]
# 3      a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 4      a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# 5      b      c                                            [(wit1, 1, 2)]
# 6      b      a                                            [(wit1, 1, 3)]
# 7      b      d                                            [(wit1, 1, 4)]
# 8      b      e                                            [(wit1, 1, 5)]
# 9      c      a                                            [(wit1, 2, 3)]
# 10     c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 11     c      e                                            [(wit1, 2, 5)]
# 12     d      e                                            [(wit1, 4, 5)]
# 13     e      c                                            [(wit2, 1, 2)]
# 14     e      d                                            [(wit2, 1, 3)]
# 15     d      b                                            [(wit3, 1, 2)]

# %%
# count witnesses for each skipgram (depth of block) and check for uniqueness of skipgram in all witnesses
#   extract sigla inside set comprehension to remove duplicates, then count
csDf["local_witnesses"] = csDf["locations"].map(lambda x: [location[0] for location in x])
csDf["unique_witnesses"]= csDf["local_witnesses"].map(lambda x: set(x))
csDf["local_witnessCount"] = csDf["local_witnesses"].str.len()
csDf["unique_witnessCount"] = csDf["unique_witnesses"].str.len()
csDf["witness_uniqueness"] = csDf["local_witnessCount"] == csDf["unique_witnessCount"]
csDf
# Out:
#    first second                                                 locations  \
# 0      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 1      a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 2      a      a                                            [(wit1, 0, 3)]
# 3      a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 4      a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# 5      b      c                                            [(wit1, 1, 2)]
# 6      b      a                                            [(wit1, 1, 3)]
# 7      b      d                                            [(wit1, 1, 4)]
# 8      b      e                                            [(wit1, 1, 5)]
# 9      c      a                                            [(wit1, 2, 3)]
# 10     c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 11     c      e                                            [(wit1, 2, 5)]
# 12     d      e                                            [(wit1, 4, 5)]
# 13     e      c                                            [(wit2, 1, 2)]
# 14     e      d                                            [(wit2, 1, 3)]
# 15     d      b                                            [(wit3, 1, 2)]
#
#              local_witnesses    unique_witnesses  local_witnessCount  \
# 0               [wit1, wit3]        {wit3, wit1}                   2
# 1               [wit1, wit2]        {wit2, wit1}                   2
# 2                     [wit1]              {wit1}                   1
# 3   [wit1, wit1, wit2, wit3]  {wit3, wit2, wit1}                   4
# 4         [wit1, wit1, wit2]        {wit2, wit1}                   3
# 5                     [wit1]              {wit1}                   1
# 6                     [wit1]              {wit1}                   1
# 7                     [wit1]              {wit1}                   1
# 8                     [wit1]              {wit1}                   1
# 9                     [wit1]              {wit1}                   1
# 10              [wit1, wit2]        {wit2, wit1}                   2
# 11                    [wit1]              {wit1}                   1
# 12                    [wit1]              {wit1}                   1
# 13                    [wit2]              {wit2}                   1
# 14                    [wit2]              {wit2}                   1
# 15                    [wit3]              {wit3}                   1
#
#     unique_witnessCount  witness_uniqueness
# 0                     2                True
# 1                     2                True
# 2                     1                True
# 3                     3               False
# 4                     2               False
# 5                     1                True
# 6                     1                True
# 7                     1                True
# 8                     1                True
# 9                     1                True
# 10                    2                True
# 11                    1                True
# 12                    1                True
# 13                    1                True
# 14                    1                True
# 15                    1                True

# %%
# are both tokens are stopwords? (if so, we’ll process them last)
csDf["stopwords"] = csDf[["first","second"]].T.isin(stoplist).all()
csDf
# Out:
#    first second                                                 locations  \
# 0      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 1      a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 2      a      a                                            [(wit1, 0, 3)]
# 3      a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 4      a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# 5      b      c                                            [(wit1, 1, 2)]
# 6      b      a                                            [(wit1, 1, 3)]
# 7      b      d                                            [(wit1, 1, 4)]
# 8      b      e                                            [(wit1, 1, 5)]
# 9      c      a                                            [(wit1, 2, 3)]
# 10     c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 11     c      e                                            [(wit1, 2, 5)]
# 12     d      e                                            [(wit1, 4, 5)]
# 13     e      c                                            [(wit2, 1, 2)]
# 14     e      d                                            [(wit2, 1, 3)]
# 15     d      b                                            [(wit3, 1, 2)]
#
#              local_witnesses    unique_witnesses  local_witnessCount  \
# 0               [wit1, wit3]        {wit3, wit1}                   2
# 1               [wit1, wit2]        {wit2, wit1}                   2
# 2                     [wit1]              {wit1}                   1
# 3   [wit1, wit1, wit2, wit3]  {wit3, wit2, wit1}                   4
# 4         [wit1, wit1, wit2]        {wit2, wit1}                   3
# 5                     [wit1]              {wit1}                   1
# 6                     [wit1]              {wit1}                   1
# 7                     [wit1]              {wit1}                   1
# 8                     [wit1]              {wit1}                   1
# 9                     [wit1]              {wit1}                   1
# 10              [wit1, wit2]        {wit2, wit1}                   2
# 11                    [wit1]              {wit1}                   1
# 12                    [wit1]              {wit1}                   1
# 13                    [wit2]              {wit2}                   1
# 14                    [wit2]              {wit2}                   1
# 15                    [wit3]              {wit3}                   1
#
#     unique_witnessCount  witness_uniqueness  stopwords
# 0                     2                True      False
# 1                     2                True       True
# 2                     1                True       True
# 3                     3               False      False
# 4                     2               False      False
# 5                     1                True      False
# 6                     1                True      False
# 7                     1                True      False
# 8                     1                True      False
# 9                     1                True       True
# 10                    2                True      False
# 11                    1                True      False
# 12                    1                True      False
# 13                    1                True      False
# 14                    1                True      False
# 15                    1                True      False

# %%
# sort and update row numbers, so that we can travese the skipgrams as follows
#   (not currently using stopword list to flter)
#   1. Words that don’t repeat within a witness first
#   2. Within that, deepest block (most witnesses) first
#   3. within that, rarest skipgrams first (less repetition is easier to place correctly)
csDf.sort_values(by=["witness_uniqueness", "unique_witnessCount", "local_witnessCount"], ascending=[False, False, True], inplace=True)
csDf.reset_index(inplace=True, drop=True) # update row numbers
csDf
# Out:
#    first second                                                 locations  \
# 0      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 1      a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 2      c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 3      a      a                                            [(wit1, 0, 3)]
# 4      b      c                                            [(wit1, 1, 2)]
# 5      b      a                                            [(wit1, 1, 3)]
# 6      b      d                                            [(wit1, 1, 4)]
# 7      b      e                                            [(wit1, 1, 5)]
# 8      c      a                                            [(wit1, 2, 3)]
# 9      c      e                                            [(wit1, 2, 5)]
# 10     d      e                                            [(wit1, 4, 5)]
# 11     e      c                                            [(wit2, 1, 2)]
# 12     e      d                                            [(wit2, 1, 3)]
# 13     d      b                                            [(wit3, 1, 2)]
# 14     a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 15     a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
#
#              local_witnesses    unique_witnesses  local_witnessCount  \
# 0               [wit1, wit3]        {wit3, wit1}                   2
# 1               [wit1, wit2]        {wit2, wit1}                   2
# 2               [wit1, wit2]        {wit2, wit1}                   2
# 3                     [wit1]              {wit1}                   1
# 4                     [wit1]              {wit1}                   1
# 5                     [wit1]              {wit1}                   1
# 6                     [wit1]              {wit1}                   1
# 7                     [wit1]              {wit1}                   1
# 8                     [wit1]              {wit1}                   1
# 9                     [wit1]              {wit1}                   1
# 10                    [wit1]              {wit1}                   1
# 11                    [wit2]              {wit2}                   1
# 12                    [wit2]              {wit2}                   1
# 13                    [wit3]              {wit3}                   1
# 14  [wit1, wit1, wit2, wit3]  {wit3, wit2, wit1}                   4
# 15        [wit1, wit1, wit2]        {wit2, wit1}                   3
#
#     unique_witnessCount  witness_uniqueness  stopwords
# 0                     2                True      False
# 1                     2                True       True
# 2                     2                True      False
# 3                     1                True       True
# 4                     1                True      False
# 5                     1                True      False
# 6                     1                True      False
# 7                     1                True      False
# 8                     1                True       True
# 9                     1                True      False
# 10                    1                True      False
# 11                    1                True      False
# 12                    1                True      False
# 13                    1                True      False
# 14                    3               False      False
# 15                    2               False      False

# %% [markdown]
# ## Construct topological order of nodes from df information

# %% [markdown]
# ### `Node` class

# %%
class Node(object):
    def __init__(self, norm):
        self.tokendata = {}  # members are tokens (witness:offset pairs); no tokens for start and end nodes
        self.norm = norm # string value of node;
            # here all values are pre-normalized, so the n value on the node is equal to the (implicit) t value on the witness tokens
            # in Real Life, witness tokens will have t values that may differ from their shared n value that appears on the node
        self.rank = None

    def __repr__(self):
        return self.norm

    def __lt__(self, other):  # make it sortable by norm value
        return self.norm < other.norm

    def add_location(self, siglum, offset):
        self.tokendata[siglum] = offset

# TODO: do we need nodes to be sortable by n value?

# %% [markdown]
# ### Debugging configuration

# %%
# for development; comment out bitArrays reset for production
for ba in bitArrays.values():  # initialize bitarrays to all 0 values
    ba.setall(0)
debug = True # controls printing of descriptive reports during processing

# %% [markdown]
# ### Construct topological order (`toList`)

# %%
# traverse rows in order
toList = []
toList.extend([Node('#start'), Node('#end')]) # initialize with start and end nodes, which have no tokens
for row in csDf.itertuples(index=False): # process df rows in order
    ###
    # each row provides first and second (normalized tokens) and offsets of instances of those tokens in witnesses
    # place by associating token, witness, and offset
    ###
    if debug:
        print("\nProcessing:", row)
    for position, norm in enumerate([row.first, row.second]): # position (0, 1) is first or second skipgram token
        for location in row.locations:
            if debug: # print current value of toList
                print("\ntoList at start of current pass is")
                for node in toList:
                    print(node, node.tokendata)
                print("\nProcessing token", norm, "(",["first", "second"][position] , 
                  "value of skipgram", ''.join([row.first, row.second]), ") in", location)
            ###
            # what siglum and offset are we looking for?
            ###
            siglum = location[0]
            offset = location[position + 1]
            if debug:
                print("Have we processed this? ", bitArrays[siglum][offset])
            ###
            # do we need to process it, or have we alreaady taken care of it?
            ###
            if bitArrays[siglum][offset]: # already set, so break for this location
                if debug:
                    print('skipping:', norm, 'from skipgram', ''.join([row.first, row.second]), 'at', location)
                continue
            else:
                pass
            ###
            # since we didn’t break, create a new node and figure out where to place it
            ###
            modifyMe = None  # flag that tells us whether we need to modify an existing node (or create a new one)
            floor = 0 # floor and ceiling frame the locations where the new node can be placed
            ceiling = len(toList) - 1
            ###
            # find floor and ceiling
            ###
            for nodePos in range(len(toList)): # determine floor and ceiling by scanning nodes
                currentDict = toList[nodePos].tokendata # keys are a list of witnesses on token
                if debug:
                    print('Finding floor and ceiling; currentDict for', toList[nodePos].norm, '= ', currentDict, "at rank", nodePos)
                if siglum not in currentDict.keys():  # this dictionary isn't relevant; look at the next one
                    pass
                else: # is it a new floor or a new ceiling? (we've already filtered out the == case)
                    if currentDict[siglum] < offset: # move up the floor if the new offset is greater than a node already there
                        floor = nodePos + 1
                    else: # we’ve hit the ceiling if the new offset is less than the old one
                        ceiling = nodePos
                        break
            if debug:
                print("Floor:", floor, "; ceiling:", ceiling)
            ###
            # scan from floor to ceiling, looking for matching 'norm' value
            #
            # if there is a dictionary to modify, save it as modifyMe (don't modify it yet)
            # TODO: this gets the leftmost if there is more than one, which is not necessarily optimal
            ###
            for pos in range(floor, ceiling):
                if toList[pos].norm == norm:
                    modifyMe = toList[pos]
                    break
            ###
            # if there is a dictionary to modify, do it; otherwise insert a new dictionary at the ceiling
            # TODO: why at the ceiling?
            ###
            if modifyMe is None: # create and insert new token
                new_token = Node(norm)
                new_token.add_location(siglum, offset)
                toList.insert(ceiling, new_token)
                if debug:
                    print('inserting', siglum,':',offset,'as rank',nodePos)
            else: # modify existing token
                if debug:
                    print('adding', siglum,':',offset,'to',modifyMe,modifyMe.tokendata,'at rank',nodePos)
                modifyMe.tokendata[siglum] = offset

            # print("Processed ", siglum, ': ', offset)
            bitArrays[siglum][offset] = 1  # record that we've processed this token
if debug:
    print(bitArrays)
# Out:
# Processing: Pandas(first='a', second='b', locations=[('wit1', 0, 1), ('wit3', 0, 2)], local_witnesses=['wit1', 'wit3'], unique_witnesses={'wit3', 'wit1'}, local_witnessCount=2, unique_witnessCount=2, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# #end {}
#
# Processing token a ( first value of skipgram ab ) in ('wit1', 0, 1)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for #end =  {} at rank 1
# Floor: 0 ; ceiling: 1
# inserting wit1 : 0 as rank 1
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0}
# #end {}
#
# Processing token a ( first value of skipgram ab ) in ('wit3', 0, 2)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0} at rank 1
# Finding floor and ceiling; currentDict for #end =  {} at rank 2
# Floor: 0 ; ceiling: 2
# adding wit3 : 0 to a {'wit1': 0} at rank 2
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0}
# #end {}
#
# Processing token b ( second value of skipgram ab ) in ('wit1', 0, 1)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0} at rank 1
# Finding floor and ceiling; currentDict for #end =  {} at rank 2
# Floor: 2 ; ceiling: 2
# inserting wit1 : 1 as rank 2
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0}
# b {'wit1': 1}
# #end {}
#
# Processing token b ( second value of skipgram ab ) in ('wit3', 0, 2)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1} at rank 2
# Finding floor and ceiling; currentDict for #end =  {} at rank 3
# Floor: 2 ; ceiling: 3
# adding wit3 : 2 to b {'wit1': 1} at rank 3
#
# Processing: Pandas(first='a', second='c', locations=[('wit1', 0, 2), ('wit2', 0, 2)], local_witnesses=['wit1', 'wit2'], unique_witnesses={'wit2', 'wit1'}, local_witnessCount=2, unique_witnessCount=2, witness_uniqueness=True, stopwords=True)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0}
# b {'wit1': 1, 'wit3': 2}
# #end {}
#
# Processing token a ( first value of skipgram ac ) in ('wit1', 0, 2)
# Have we processed this?  True
# skipping: a from skipgram ac at ('wit1', 0, 2)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0}
# b {'wit1': 1, 'wit3': 2}
# #end {}
#
# Processing token a ( first value of skipgram ac ) in ('wit2', 0, 2)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Finding floor and ceiling; currentDict for #end =  {} at rank 3
# Floor: 0 ; ceiling: 3
# adding wit2 : 0 to a {'wit1': 0, 'wit3': 0} at rank 3
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# #end {}
#
# Processing token c ( second value of skipgram ac ) in ('wit1', 0, 2)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0, 'wit2': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Finding floor and ceiling; currentDict for #end =  {} at rank 3
# Floor: 3 ; ceiling: 3
# inserting wit1 : 2 as rank 3
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2}
# #end {}
#
# Processing token c ( second value of skipgram ac ) in ('wit2', 0, 2)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0, 'wit2': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Finding floor and ceiling; currentDict for c =  {'wit1': 2} at rank 3
# Finding floor and ceiling; currentDict for #end =  {} at rank 4
# Floor: 2 ; ceiling: 4
# adding wit2 : 2 to c {'wit1': 2} at rank 4
#
# Processing: Pandas(first='c', second='d', locations=[('wit1', 2, 4), ('wit2', 2, 3)], local_witnesses=['wit1', 'wit2'], unique_witnesses={'wit2', 'wit1'}, local_witnessCount=2, unique_witnessCount=2, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# #end {}
#
# Processing token c ( first value of skipgram cd ) in ('wit1', 2, 4)
# Have we processed this?  True
# skipping: c from skipgram cd at ('wit1', 2, 4)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# #end {}
#
# Processing token c ( first value of skipgram cd ) in ('wit2', 2, 3)
# Have we processed this?  True
# skipping: c from skipgram cd at ('wit2', 2, 3)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# #end {}
#
# Processing token d ( second value of skipgram cd ) in ('wit1', 2, 4)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0, 'wit2': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Finding floor and ceiling; currentDict for c =  {'wit1': 2, 'wit2': 2} at rank 3
# Finding floor and ceiling; currentDict for #end =  {} at rank 4
# Floor: 4 ; ceiling: 4
# inserting wit1 : 4 as rank 4
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# d {'wit1': 4}
# #end {}
#
# Processing token d ( second value of skipgram cd ) in ('wit2', 2, 3)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0, 'wit2': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Finding floor and ceiling; currentDict for c =  {'wit1': 2, 'wit2': 2} at rank 3
# Finding floor and ceiling; currentDict for d =  {'wit1': 4} at rank 4
# Finding floor and ceiling; currentDict for #end =  {} at rank 5
# Floor: 4 ; ceiling: 5
# adding wit2 : 3 to d {'wit1': 4} at rank 5
#
# Processing: Pandas(first='a', second='a', locations=[('wit1', 0, 3)], local_witnesses=['wit1'], unique_witnesses={'wit1'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=True)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token a ( first value of skipgram aa ) in ('wit1', 0, 3)
# Have we processed this?  True
# skipping: a from skipgram aa at ('wit1', 0, 3)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token a ( second value of skipgram aa ) in ('wit1', 0, 3)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0, 'wit2': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Finding floor and ceiling; currentDict for c =  {'wit1': 2, 'wit2': 2} at rank 3
# Finding floor and ceiling; currentDict for d =  {'wit1': 4, 'wit2': 3} at rank 4
# Floor: 4 ; ceiling: 4
# inserting wit1 : 3 as rank 4
#
# Processing: Pandas(first='b', second='c', locations=[('wit1', 1, 2)], local_witnesses=['wit1'], unique_witnesses={'wit1'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token b ( first value of skipgram bc ) in ('wit1', 1, 2)
# Have we processed this?  True
# skipping: b from skipgram bc at ('wit1', 1, 2)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token c ( second value of skipgram bc ) in ('wit1', 1, 2)
# Have we processed this?  True
# skipping: c from skipgram bc at ('wit1', 1, 2)
#
# Processing: Pandas(first='b', second='a', locations=[('wit1', 1, 3)], local_witnesses=['wit1'], unique_witnesses={'wit1'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token b ( first value of skipgram ba ) in ('wit1', 1, 3)
# Have we processed this?  True
# skipping: b from skipgram ba at ('wit1', 1, 3)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token a ( second value of skipgram ba ) in ('wit1', 1, 3)
# Have we processed this?  True
# skipping: a from skipgram ba at ('wit1', 1, 3)
#
# Processing: Pandas(first='b', second='d', locations=[('wit1', 1, 4)], local_witnesses=['wit1'], unique_witnesses={'wit1'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token b ( first value of skipgram bd ) in ('wit1', 1, 4)
# Have we processed this?  True
# skipping: b from skipgram bd at ('wit1', 1, 4)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token d ( second value of skipgram bd ) in ('wit1', 1, 4)
# Have we processed this?  True
# skipping: d from skipgram bd at ('wit1', 1, 4)
#
# Processing: Pandas(first='b', second='e', locations=[('wit1', 1, 5)], local_witnesses=['wit1'], unique_witnesses={'wit1'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token b ( first value of skipgram be ) in ('wit1', 1, 5)
# Have we processed this?  True
# skipping: b from skipgram be at ('wit1', 1, 5)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# #end {}
#
# Processing token e ( second value of skipgram be ) in ('wit1', 1, 5)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0, 'wit2': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Finding floor and ceiling; currentDict for c =  {'wit1': 2, 'wit2': 2} at rank 3
# Finding floor and ceiling; currentDict for a =  {'wit1': 3} at rank 4
# Finding floor and ceiling; currentDict for d =  {'wit1': 4, 'wit2': 3} at rank 5
# Finding floor and ceiling; currentDict for #end =  {} at rank 6
# Floor: 6 ; ceiling: 6
# inserting wit1 : 5 as rank 6
#
# Processing: Pandas(first='c', second='a', locations=[('wit1', 2, 3)], local_witnesses=['wit1'], unique_witnesses={'wit1'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=True)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token c ( first value of skipgram ca ) in ('wit1', 2, 3)
# Have we processed this?  True
# skipping: c from skipgram ca at ('wit1', 2, 3)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token a ( second value of skipgram ca ) in ('wit1', 2, 3)
# Have we processed this?  True
# skipping: a from skipgram ca at ('wit1', 2, 3)
#
# Processing: Pandas(first='c', second='e', locations=[('wit1', 2, 5)], local_witnesses=['wit1'], unique_witnesses={'wit1'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token c ( first value of skipgram ce ) in ('wit1', 2, 5)
# Have we processed this?  True
# skipping: c from skipgram ce at ('wit1', 2, 5)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token e ( second value of skipgram ce ) in ('wit1', 2, 5)
# Have we processed this?  True
# skipping: e from skipgram ce at ('wit1', 2, 5)
#
# Processing: Pandas(first='d', second='e', locations=[('wit1', 4, 5)], local_witnesses=['wit1'], unique_witnesses={'wit1'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token d ( first value of skipgram de ) in ('wit1', 4, 5)
# Have we processed this?  True
# skipping: d from skipgram de at ('wit1', 4, 5)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token e ( second value of skipgram de ) in ('wit1', 4, 5)
# Have we processed this?  True
# skipping: e from skipgram de at ('wit1', 4, 5)
#
# Processing: Pandas(first='e', second='c', locations=[('wit2', 1, 2)], local_witnesses=['wit2'], unique_witnesses={'wit2'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token e ( first value of skipgram ec ) in ('wit2', 1, 2)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0, 'wit2': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Finding floor and ceiling; currentDict for c =  {'wit1': 2, 'wit2': 2} at rank 3
# Floor: 2 ; ceiling: 3
# inserting wit2 : 1 as rank 3
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token c ( second value of skipgram ec ) in ('wit2', 1, 2)
# Have we processed this?  True
# skipping: c from skipgram ec at ('wit2', 1, 2)
#
# Processing: Pandas(first='e', second='d', locations=[('wit2', 1, 3)], local_witnesses=['wit2'], unique_witnesses={'wit2'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token e ( first value of skipgram ed ) in ('wit2', 1, 3)
# Have we processed this?  True
# skipping: e from skipgram ed at ('wit2', 1, 3)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token d ( second value of skipgram ed ) in ('wit2', 1, 3)
# Have we processed this?  True
# skipping: d from skipgram ed at ('wit2', 1, 3)
#
# Processing: Pandas(first='d', second='b', locations=[('wit3', 1, 2)], local_witnesses=['wit3'], unique_witnesses={'wit3'}, local_witnessCount=1, unique_witnessCount=1, witness_uniqueness=True, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token d ( first value of skipgram db ) in ('wit3', 1, 2)
# Have we processed this?  False
# Finding floor and ceiling; currentDict for #start =  {} at rank 0
# Finding floor and ceiling; currentDict for a =  {'wit1': 0, 'wit3': 0, 'wit2': 0} at rank 1
# Finding floor and ceiling; currentDict for b =  {'wit1': 1, 'wit3': 2} at rank 2
# Floor: 2 ; ceiling: 2
# inserting wit3 : 1 as rank 2
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token b ( second value of skipgram db ) in ('wit3', 1, 2)
# Have we processed this?  True
# skipping: b from skipgram db at ('wit3', 1, 2)
#
# Processing: Pandas(first='a', second='d', locations=[('wit1', 0, 4), ('wit1', 3, 4), ('wit2', 0, 3), ('wit3', 0, 1)], local_witnesses=['wit1', 'wit1', 'wit2', 'wit3'], unique_witnesses={'wit3', 'wit2', 'wit1'}, local_witnessCount=4, unique_witnessCount=3, witness_uniqueness=False, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token a ( first value of skipgram ad ) in ('wit1', 0, 4)
# Have we processed this?  True
# skipping: a from skipgram ad at ('wit1', 0, 4)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token a ( first value of skipgram ad ) in ('wit1', 3, 4)
# Have we processed this?  True
# skipping: a from skipgram ad at ('wit1', 3, 4)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token a ( first value of skipgram ad ) in ('wit2', 0, 3)
# Have we processed this?  True
# skipping: a from skipgram ad at ('wit2', 0, 3)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token a ( first value of skipgram ad ) in ('wit3', 0, 1)
# Have we processed this?  True
# skipping: a from skipgram ad at ('wit3', 0, 1)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token d ( second value of skipgram ad ) in ('wit1', 0, 4)
# Have we processed this?  True
# skipping: d from skipgram ad at ('wit1', 0, 4)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token d ( second value of skipgram ad ) in ('wit1', 3, 4)
# Have we processed this?  True
# skipping: d from skipgram ad at ('wit1', 3, 4)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token d ( second value of skipgram ad ) in ('wit2', 0, 3)
# Have we processed this?  True
# skipping: d from skipgram ad at ('wit2', 0, 3)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token d ( second value of skipgram ad ) in ('wit3', 0, 1)
# Have we processed this?  True
# skipping: d from skipgram ad at ('wit3', 0, 1)
#
# Processing: Pandas(first='a', second='e', locations=[('wit1', 0, 5), ('wit1', 3, 5), ('wit2', 0, 1)], local_witnesses=['wit1', 'wit1', 'wit2'], unique_witnesses={'wit2', 'wit1'}, local_witnessCount=3, unique_witnessCount=2, witness_uniqueness=False, stopwords=False)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token a ( first value of skipgram ae ) in ('wit1', 0, 5)
# Have we processed this?  True
# skipping: a from skipgram ae at ('wit1', 0, 5)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token a ( first value of skipgram ae ) in ('wit1', 3, 5)
# Have we processed this?  True
# skipping: a from skipgram ae at ('wit1', 3, 5)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token a ( first value of skipgram ae ) in ('wit2', 0, 1)
# Have we processed this?  True
# skipping: a from skipgram ae at ('wit2', 0, 1)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token e ( second value of skipgram ae ) in ('wit1', 0, 5)
# Have we processed this?  True
# skipping: e from skipgram ae at ('wit1', 0, 5)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token e ( second value of skipgram ae ) in ('wit1', 3, 5)
# Have we processed this?  True
# skipping: e from skipgram ae at ('wit1', 3, 5)
#
# toList at start of current pass is
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
#
# Processing token e ( second value of skipgram ae ) in ('wit2', 0, 1)
# Have we processed this?  True
# skipping: e from skipgram ae at ('wit2', 0, 1)
# {'wit1': bitarray('111111'), 'wit2': bitarray('1111'), 'wit3': bitarray('111')}

# %% [markdown]
# ### Build list of edges for each witness

# %%
edgeSets = collections.defaultdict(list)  # key = siglum, value = list of node (source, target) tuples
edgeSourceByWitness = {}  # last target will be next source
for node in toList:  # token.norm is str; token.tokendata is dict with siglum:offset items
    if node.norm == '#start':  # not an edge target, so don’t add an edge, but set up source for next edge
        for siglum in witnessData:
            edgeSourceByWitness[siglum] = node
    elif node.norm == '#end':  # create edges to #end for all witnesses
        for siglum in witnessData:
            edgeSets[siglum].append((edgeSourceByWitness[siglum], node))
    else:
        for key, value in node.tokendata.items():
            # add next witness-specific edge, update value in edgeSourceByWitness
            edgeSets[key].append((edgeSourceByWitness[key], node))
            edgeSourceByWitness[key] = node
edges = set(inner for outer in edgeSets.values() for inner in outer)  # tuples of Tokens

# %% [markdown]
# ### Index from edge target to source for calculating rank

# %%
findMySources = collections.defaultdict(list)
for edge in edges:
    findMySources[edge[1]].append(edge[0])

# %% [markdown]
# ### Rank nodes in toList

# %%
for item in toList:
    inEdges = findMySources[item]
    item.rank = max([r.rank for r in inEdges], default=-1) + 1
node_table = pd.DataFrame([(item, item.tokendata, item.rank) for item in toList])
node_table.columns = ["norm", "tokendata", "rank"]
node_table
# Out:
#      norm                          tokendata  rank
# 0  #start                                 {}     0
# 1       a  {'wit1': 0, 'wit3': 0, 'wit2': 0}     1
# 2       d                        {'wit3': 1}     2
# 3       b             {'wit1': 1, 'wit3': 2}     3
# 4       e                        {'wit2': 1}     2
# 5       c             {'wit1': 2, 'wit2': 2}     4
# 6       a                        {'wit1': 3}     5
# 7       d             {'wit1': 4, 'wit2': 3}     6
# 8       e                        {'wit1': 5}     7
# 9    #end                                 {}     8

# %% [markdown]
# ### Index from rank to nodes for retrieval when building table by columns/ranks

# %%
nodesByRank = collections.defaultdict(list)
for node in toList:
    nodesByRank[node.rank].append(node)

# %% [markdown]
# ## Create alignment table

# %%
table = PrettyTable(header=False)
orderedSigla = sorted(witnessData.keys())
table.add_column(None,[key for key in orderedSigla])
for rank, nodes in nodesByRank.items():  # add a column for each rank
    columnTokens = {}
    for node in nodes:  # copy tokens from all nodes at rank into a single dictionary; value is string (not offset)
        for key in node.tokendata.keys():
            columnTokens[key] = node.norm                
    columnData = []
    for siglum in orderedSigla:
        if siglum in columnTokens:
            columnData.append(columnTokens[siglum])
        elif node.norm in ["#start", "#end"]:
            columnData.append(node.norm)
        else:
            columnData.append('')
    table.add_column(None, columnData)
print(table)
# Out:
# +------+--------+---+---+---+---+---+---+---+------+
# | wit1 | #start | a |   | b | c | a | d | e | #end |
# | wit2 | #start | a | e |   | c |   | d |   | #end |
# | wit3 | #start | a | d | b |   |   |   |   | #end |
# +------+--------+---+---+---+---+---+---+---+------+

# %% [markdown]
# ### Expected output
#
# siglum | token | token | token | token | token | token | token | token
# ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ----
# wit1  | #start | a | b | c | a | d | e | #end
# wit2  | #start | a | e | c | - | d | - | #end
# wit3  | #start | a | - | - | - | d | b | #end

# %% [markdown]
# ## Optional df profiling information

# %%
if debug:
    for node in toList:
        print(node, node.tokendata)
    profile = pandas_profiling.ProfileReport(csDf)
    display(profile)
# Out:
# #start {}
# a {'wit1': 0, 'wit3': 0, 'wit2': 0}
# d {'wit3': 1}
# b {'wit1': 1, 'wit3': 2}
# e {'wit2': 1}
# c {'wit1': 2, 'wit2': 2}
# a {'wit1': 3}
# d {'wit1': 4, 'wit2': 3}
# e {'wit1': 5}
# #end {}
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>16 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>1008.0 B </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>63.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>3 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_local_witnesses"><code>local_witnesses</code></a> is an unsupported type, check if it needs cleaning or further analysis <span class="label label-warning">Warning</span></li><li><a href="#pp_var_locations"><code>locations</code></a> is an unsupported type, check if it needs cleaning or further analysis <span class="label label-warning">Warning</span></li><li><a href="#pp_var_unique_witnessCount"><code>unique_witnessCount</code></a> is highly correlated with <a href="#pp_var_local_witnessCount"><code>local_witnessCount</code></a> (ρ = 0.96309) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_unique_witnesses"><code>unique_witnesses</code></a> is an unsupported type, check if it needs cleaning or further analysis <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_first">first<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>

# %%
# for skipgram in csList: # skipgram is a tuple of skipgram items
#     locations = csTable[skipgram]  # list of three-item tuples of (siglum, location0, location1)
#     for skipgramPos in range(len(skipgram)):  # loop over head and tail by position ([0, 1])
#         norm = skipgram[skipgramPos]  # get normalized value of each token in skipgram by position
#         for location in locations:  # for each token, get witness and offset within witness
#             siglum = location[0]  # witness identifier
#             offset = location[skipgramPos + 1]  # offset of token within witness
#             if bitArrays[siglum][offset] == 1: # already set, so break for this location
#                 # print('skipping: ', norm, ' from ', skipgram, ' at ', location)
#                 break
#             floor = 0
#             ceiling = len(toList) - 1
#             modifyMe = None  # existing toList entry to be modified; if None, create a new one
#             for dictPos in range(len(toList)): # determine floor and ceiling
#                 currentDict = toList[dictPos].tokendata
#                 if siglum not in currentDict.keys():  # dictionary isn't relevant; check the next item in toList
#                     pass
#                 else:  # it can't be equal, since we used the bitarray to filter those out
#                     if currentDict[siglum] < offset:
#                         floor = dictPos
#                     else:
#                         ceiling = dictPos
#                         break
#             # scan from floor to ceiling, looking for matching 'norm' value
#             # if there is a dictionary to modify, save it as modifyMe (don't modify it yet)
#             # TODO: this gets the leftmost if there is more than one, which is not necessarily optimal
#             for pos in range(floor, ceiling):
#                 if toList[pos].norm == norm:
#                     modifyMe = toList[pos]
#                     break
#             # if there is a dictionary to modify, do it; otherwise insert a new dictionary at the ceiling
#             if modifyMe is None:
#                 new_token = Node(norm)
#                     new_token.add_location(siglum, offset)
#                     toList.insert(ceiling, new_token)
#                 else:
#                     # print('adding', siglum,':',offset,'to',modifyMe,modifyMe.tokendata)
#                     modifyMe.tokendata[siglum] = offset
#                 bitArrays[siglum][offset] = 1  # record that we've processed this token
#                 # print('added: ', norm, ' from ', skipgram, ' at ', location,
#                 #       ' with floor=', floor, ' and ceiling=', ceiling, sep='')
