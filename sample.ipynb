# %% [markdown]
# # Multiple witness alignment with skipgrams, pandas version

# %%
import pandas as pd
import collections # for defaultdict
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 150)

# %%
# sample data and fake stoplist
witnessData = {'wit1': ['a', 'b', 'c', 'a', 'd', 'e'],
               'wit2': ['a', 'e', 'c', 'd'],
               'wit3': ['a', 'd', 'b']}
stoplist = {'a', 'c'} # set

# %%
# csTable: list of dictionaries, in each of which
#   key is a two-item tuple representing skipgram tokens: (token[0], token[1])
#   value is a list of three-item tuples where the skipgram key occurs: (siglum, offset[0], offset[1])
csTable = collections.defaultdict(list)
for key, value in witnessData.items():
    for first in range(len(value)):
        for second in range(first + 1, len(value)):
            csTable[(value[first], value[second])].append((key, first, second))
csTable
# Out:
# defaultdict(list,
#             {('a', 'b'): [('wit1', 0, 1), ('wit3', 0, 2)],
#              ('a', 'c'): [('wit1', 0, 2), ('wit2', 0, 2)],
#              ('a', 'a'): [('wit1', 0, 3)],
#              ('a', 'd'): [('wit1', 0, 4),
#               ('wit1', 3, 4),
#               ('wit2', 0, 3),
#               ('wit3', 0, 1)],
#              ('a', 'e'): [('wit1', 0, 5), ('wit1', 3, 5), ('wit2', 0, 1)],
#              ('b', 'c'): [('wit1', 1, 2)],
#              ('b', 'a'): [('wit1', 1, 3)],
#              ('b', 'd'): [('wit1', 1, 4)],
#              ('b', 'e'): [('wit1', 1, 5)],
#              ('c', 'a'): [('wit1', 2, 3)],
#              ('c', 'd'): [('wit1', 2, 4), ('wit2', 2, 3)],
#              ('c', 'e'): [('wit1', 2, 5)],
#              ('d', 'e'): [('wit1', 4, 5)],
#              ('e', 'c'): [('wit2', 1, 2)],
#              ('e', 'd'): [('wit2', 1, 3)],
#              ('d', 'b'): [('wit3', 1, 2)]})

# %%
# convert to series before df since list lengths vary
csSeries = pd.Series(csTable)
csSeries
# Out:
# a  b                                [(wit1, 0, 1), (wit3, 0, 2)]
#    c                                [(wit1, 0, 2), (wit2, 0, 2)]
#    a                                              [(wit1, 0, 3)]
#    d    [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
#    e                  [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# b  c                                              [(wit1, 1, 2)]
#    a                                              [(wit1, 1, 3)]
#    d                                              [(wit1, 1, 4)]
#    e                                              [(wit1, 1, 5)]
# c  a                                              [(wit1, 2, 3)]
#    d                                [(wit1, 2, 4), (wit2, 2, 3)]
#    e                                              [(wit1, 2, 5)]
# d  e                                              [(wit1, 4, 5)]
# e  c                                              [(wit2, 1, 2)]
#    d                                              [(wit2, 1, 3)]
# d  b                                              [(wit3, 1, 2)]
# dtype: object

# %%
# convert series to dataframe, flatten multi-index, label columns
csDf = pd.DataFrame(csSeries).reset_index()
csDf.columns = ["first", "second", "locations"]
csDf
# Out:
#    first second                                                 locations
# 0      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 1      a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 2      a      a                                            [(wit1, 0, 3)]
# 3      a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 4      a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# 5      b      c                                            [(wit1, 1, 2)]
# 6      b      a                                            [(wit1, 1, 3)]
# 7      b      d                                            [(wit1, 1, 4)]
# 8      b      e                                            [(wit1, 1, 5)]
# 9      c      a                                            [(wit1, 2, 3)]
# 10     c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 11     c      e                                            [(wit1, 2, 5)]
# 12     d      e                                            [(wit1, 4, 5)]
# 13     e      c                                            [(wit2, 1, 2)]
# 14     e      d                                            [(wit2, 1, 3)]
# 15     d      b                                            [(wit3, 1, 2)]

# %%
# count witnesses for each skipgram (depth)
csDf["witnessCount"] = csDf["locations"].apply(lambda locationList: len({location[0] for location in locationList}))
csDf
# Out:
#    first second                                                 locations  \
# 0      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 1      a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 2      a      a                                            [(wit1, 0, 3)]
# 3      a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 4      a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# 5      b      c                                            [(wit1, 1, 2)]
# 6      b      a                                            [(wit1, 1, 3)]
# 7      b      d                                            [(wit1, 1, 4)]
# 8      b      e                                            [(wit1, 1, 5)]
# 9      c      a                                            [(wit1, 2, 3)]
# 10     c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 11     c      e                                            [(wit1, 2, 5)]
# 12     d      e                                            [(wit1, 4, 5)]
# 13     e      c                                            [(wit2, 1, 2)]
# 14     e      d                                            [(wit2, 1, 3)]
# 15     d      b                                            [(wit3, 1, 2)]
#
#     witnessCount
# 0              2
# 1              2
# 2              1
# 3              3
# 4              2
# 5              1
# 6              1
# 7              1
# 8              1
# 9              1
# 10             2
# 11             1
# 12             1
# 13             1
# 14             1
# 15             1

# %%
# count total frequency of each skipgram
csDf["locationCount"] = csDf["locations"].apply(lambda x: len(x))
csDf
# Out:
#    first second                                                 locations  \
# 0      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 1      a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 2      a      a                                            [(wit1, 0, 3)]
# 3      a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 4      a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# 5      b      c                                            [(wit1, 1, 2)]
# 6      b      a                                            [(wit1, 1, 3)]
# 7      b      d                                            [(wit1, 1, 4)]
# 8      b      e                                            [(wit1, 1, 5)]
# 9      c      a                                            [(wit1, 2, 3)]
# 10     c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 11     c      e                                            [(wit1, 2, 5)]
# 12     d      e                                            [(wit1, 4, 5)]
# 13     e      c                                            [(wit2, 1, 2)]
# 14     e      d                                            [(wit2, 1, 3)]
# 15     d      b                                            [(wit3, 1, 2)]
#
#     witnessCount  locationCount
# 0              2              2
# 1              2              2
# 2              1              1
# 3              3              4
# 4              2              3
# 5              1              1
# 6              1              1
# 7              1              1
# 8              1              1
# 9              1              1
# 10             2              2
# 11             1              1
# 12             1              1
# 13             1              1
# 14             1              1
# 15             1              1

# %%
# are both tokens are stopwords?
csDf["stopwords"] = csDf[["first","second"]].T.isin(stoplist).all()
csDf
# Out:
#    first second                                                 locations  \
# 0      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 1      a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 2      a      a                                            [(wit1, 0, 3)]
# 3      a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 4      a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# 5      b      c                                            [(wit1, 1, 2)]
# 6      b      a                                            [(wit1, 1, 3)]
# 7      b      d                                            [(wit1, 1, 4)]
# 8      b      e                                            [(wit1, 1, 5)]
# 9      c      a                                            [(wit1, 2, 3)]
# 10     c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 11     c      e                                            [(wit1, 2, 5)]
# 12     d      e                                            [(wit1, 4, 5)]
# 13     e      c                                            [(wit2, 1, 2)]
# 14     e      d                                            [(wit2, 1, 3)]
# 15     d      b                                            [(wit3, 1, 2)]
#
#     witnessCount  locationCount  stopwords
# 0              2              2      False
# 1              2              2       True
# 2              1              1       True
# 3              3              4      False
# 4              2              3      False
# 5              1              1      False
# 6              1              1      False
# 7              1              1      False
# 8              1              1      False
# 9              1              1       True
# 10             2              2      False
# 11             1              1      False
# 12             1              1      False
# 13             1              1      False
# 14             1              1      False
# 15             1              1      False

# %%
# sort in place and update row numbers for new order
#   stopword pairs last
#   deepest first
#   rarest first
csDf.sort_values(by=["stopwords", "witnessCount", "locationCount"], ascending=[True, False, True], inplace=True)
csDf.reset_index(inplace=True, drop=True)
csDf
# Out:
#    first second                                                 locations  \
# 0      a      d  [(wit1, 0, 4), (wit1, 3, 4), (wit2, 0, 3), (wit3, 0, 1)]
# 1      a      b                              [(wit1, 0, 1), (wit3, 0, 2)]
# 2      c      d                              [(wit1, 2, 4), (wit2, 2, 3)]
# 3      a      e                [(wit1, 0, 5), (wit1, 3, 5), (wit2, 0, 1)]
# 4      b      c                                            [(wit1, 1, 2)]
# 5      b      a                                            [(wit1, 1, 3)]
# 6      b      d                                            [(wit1, 1, 4)]
# 7      b      e                                            [(wit1, 1, 5)]
# 8      c      e                                            [(wit1, 2, 5)]
# 9      d      e                                            [(wit1, 4, 5)]
# 10     e      c                                            [(wit2, 1, 2)]
# 11     e      d                                            [(wit2, 1, 3)]
# 12     d      b                                            [(wit3, 1, 2)]
# 13     a      c                              [(wit1, 0, 2), (wit2, 0, 2)]
# 14     a      a                                            [(wit1, 0, 3)]
# 15     c      a                                            [(wit1, 2, 3)]
#
#     witnessCount  locationCount  stopwords
# 0              3              4      False
# 1              2              2      False
# 2              2              2      False
# 3              2              3      False
# 4              1              1      False
# 5              1              1      False
# 6              1              1      False
# 7              1              1      False
# 8              1              1      False
# 9              1              1      False
# 10             1              1      False
# 11             1              1      False
# 12             1              1      False
# 13             2              2       True
# 14             1              1       True
# 15             1              1       True

# %%
# iterate over rows in order
for index, row in csDf.iterrows():
    print(row["locations"])
# Out:
# [('wit1', 0, 4), ('wit1', 3, 4), ('wit2', 0, 3), ('wit3', 0, 1)]
# [('wit1', 0, 1), ('wit3', 0, 2)]
# [('wit1', 2, 4), ('wit2', 2, 3)]
# [('wit1', 0, 5), ('wit1', 3, 5), ('wit2', 0, 1)]
# [('wit1', 1, 2)]
# [('wit1', 1, 3)]
# [('wit1', 1, 4)]
# [('wit1', 1, 5)]
# [('wit1', 2, 5)]
# [('wit1', 4, 5)]
# [('wit2', 1, 2)]
# [('wit2', 1, 3)]
# [('wit3', 1, 2)]
# [('wit1', 0, 2), ('wit2', 0, 2)]
# [('wit1', 0, 3)]
# [('wit1', 2, 3)]
